# %%
import yfinance as yf
import pandas as pd

import datetime

# %%
data = yf.download(
                "TSLA", 
                start=datetime.datetime.now() - datetime.timedelta(days=20), 
                end=datetime.datetime.now()
            )
data = data.tail(14)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           TSLA        TSLA        TSLA        TSLA
# Date
# 2024-10-22 00:00:00+00:00  217.970001  217.970001  218.220001  215.259995
# 2024-10-23 00:00:00+00:00  213.649994  213.649994  218.720001  212.110001
# 2024-10-24 00:00:00+00:00  260.480011  260.480011  262.119995  242.649994
# 2024-10-25 00:00:00+00:00  269.190002  269.190002  269.489990  255.320007
# 2024-10-28 00:00:00+00:00  262.510010  262.510010  273.540009  262.239990
# 2024-10-29 00:00:00+00:00  259.519989  259.519989  264.980011  255.509995
# 2024-10-30 00:00:00+00:00  257.549988  257.549988  263.350006  255.820007
# 2024-10-31 00:00:00+00:00  249.850006  249.850006  259.750000  249.250000
# 2024-11-01 00:00:00+00:00  248.979996  248.979996  254.000000  246.630005
# 2024-11-04 00:00:00+00:00  242.839996  242.839996  248.899994  238.880005
# ...

# %%
close_series = data[("Close", "TSLA")]

# %%
close_series[0]
# Out:
# 217.97000122070312

# %%
data
# Out:
# Price  level_0 index                      Date   Adj Close       Close  \
# Ticker                                                TSLA        TSLA
# 0            0     0 2024-10-22 00:00:00+00:00  217.970001  217.970001
# 1            1     1 2024-10-23 00:00:00+00:00  213.649994  213.649994
# 2            2     2 2024-10-24 00:00:00+00:00  260.480011  260.480011
# 3            3     3 2024-10-25 00:00:00+00:00  269.190002  269.190002
# 4            4     4 2024-10-28 00:00:00+00:00  262.510010  262.510010
# 5            5     5 2024-10-29 00:00:00+00:00  259.519989  259.519989
# 6            6     6 2024-10-30 00:00:00+00:00  257.549988  257.549988
# 7            7     7 2024-10-31 00:00:00+00:00  249.850006  249.850006
# 8            8     8 2024-11-01 00:00:00+00:00  248.979996  248.979996
# 9            9     9 2024-11-04 00:00:00+00:00  242.839996  242.839996
# 10          10    10 2024-11-05 00:00:00+00:00  251.440002  251.440002
# ...
